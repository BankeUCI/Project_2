# %%
import pandas as pd
import matplotlib.pyplot as plt
# import wbgapi as wb
# from scipy.stats import linregress

# %% [markdown]
# ## Extract Data
# ### Create reference data:
#
# #### Countries allowed:
# * Number of Gold Medals >0 & Rank by Total Medals <=20
#
# #### Medal types:
# * Gold & Total

# %%
from sqlalchemy import create_engine
import sqlalchemy

# %%
# Path to sqlite
database_path = '../Resources/Medals.xlsx'

# %%
engine = create_engine(f"excel:///?Excel File={database_path}")
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-42-45d666662865> in <module>
# ----> 1 engine = create_engine(f"excel:///?Excel File={database_path}")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     498     strategy = kwargs.pop("strategy", default_strategy)
#     499     strategy = strategies.strategies[strategy]
# --> 500     return strategy.create(*args, **kwargs)
#     501
#     502
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      59         kwargs.pop("plugins", None)
#      60
# ---> 61         entrypoint = u._get_entrypoint()
#      62         dialect_cls = entrypoint.get_dialect_cls(u)
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/url.py in _get_entrypoint(self)
# ...

# %%
engine = create_engine("excel:///?Excel File='C:/MyExcelWorkbooks/SampleWorkbook.xlsx'")

# %%
# Load data about all athletes to dataframe
athl_path = "../Resources/Athletes.csv"
all_athl = pd.read_csv(athl_path)
all_athl
# Out:
#                         Name      NOC           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [11085 rows x 3 columns]

# %%
# Apply BR: Each cell should contain a single value

# Split Name column values into two separated columns
columnsplit = all_athl['Name'].str.split(" ", expand=True)
all_athl = all_athl.assign(Last_name=columnsplit[0],First_name=columnsplit[1])
all_athl.head()
# Out:
#                 Name     NOC           Discipline Last_name First_name
# 0    AALERUD Katrine  Norway         Cycling Road   AALERUD    Katrine
# 1        ABAD Nestor   Spain  Artistic Gymnastics      ABAD     Nestor
# 2  ABAGNALE Giovanni   Italy               Rowing  ABAGNALE   Giovanni
# 3     ABALDE Alberto   Spain           Basketball    ABALDE    Alberto
# 4      ABALDE Tamara   Spain           Basketball    ABALDE     Tamara

# %%
# Drop Name column
all_athl = all_athl.drop(['Name'], axis=1)
all_athl.head()
# Out:
#       NOC           Discipline Last_name First_name
# 0  Norway         Cycling Road   AALERUD    Katrine
# 1   Spain  Artistic Gymnastics      ABAD     Nestor
# 2   Italy               Rowing  ABAGNALE   Giovanni
# 3   Spain           Basketball    ABALDE    Alberto
# 4   Spain           Basketball    ABALDE     Tamara

# %%
# Reorder columns
all_athl = all_athl[["Last_name","First_name", "NOC", "Discipline"]]
all_athl
# Out:
#        Last_name First_name      NOC           Discipline
# 0        AALERUD    Katrine   Norway         Cycling Road
# 1           ABAD     Nestor    Spain  Artistic Gymnastics
# 2       ABAGNALE   Giovanni    Italy               Rowing
# 3         ABALDE    Alberto    Spain           Basketball
# 4         ABALDE     Tamara    Spain           Basketball
# ...          ...        ...      ...                  ...
# 11080    ZWICKER     Martin  Germany               Hockey
# 11081  ZWOLINSKA    Klaudia   Poland         Canoe Slalom
# 11082     ZYKOVA      Yulia      ROC             Shooting
# 11083    ZYUZINA  Ekaterina      ROC              Sailing
# 11084   ZYZANSKA     Sylwia   Poland              Archery
#
# [11085 rows x 4 columns]

# %%
# Apply BR: Values in cells should be Capitalized
all_athl['Last_name'] = all_athl['Last_name'].str.capitalize()
all_athl
# Out:
#        Last_name First_name      NOC           Discipline
# 0        Aalerud    Katrine   Norway         Cycling Road
# 1           Abad     Nestor    Spain  Artistic Gymnastics
# 2       Abagnale   Giovanni    Italy               Rowing
# 3         Abalde    Alberto    Spain           Basketball
# 4         Abalde     Tamara    Spain           Basketball
# ...          ...        ...      ...                  ...
# 11080    Zwicker     Martin  Germany               Hockey
# 11081  Zwolinska    Klaudia   Poland         Canoe Slalom
# 11082     Zykova      Yulia      ROC             Shooting
# 11083    Zyuzina  Ekaterina      ROC              Sailing
# 11084   Zyzanska     Sylwia   Poland              Archery
#
# [11085 rows x 4 columns]

# %%
# Load data about all teams to dataframe
team_path = "../Resources/Teams.csv"
all_team = pd.read_csv(team_path)
all_team
# Out:
#               Name      Discipline                         NOC  Event
# 0          Belgium  3x3 Basketball                     Belgium    Men
# 1            China  3x3 Basketball  People's Republic of China    Men
# 2            China  3x3 Basketball  People's Republic of China  Women
# 3           France  3x3 Basketball                      France  Women
# 4            Italy  3x3 Basketball                       Italy  Women
# ..             ...             ...                         ...    ...
# 738   South Africa      Water Polo                South Africa  Women
# 739          Spain      Water Polo                       Spain    Men
# 740          Spain      Water Polo                       Spain  Women
# 741  United States      Water Polo    United States of America    Men
# 742  United States      Water Polo    United States of America  Women
#
# [743 rows x 4 columns]

# %%
# Check on one discpiline first
disciplines = all_team['Discipline'].unique()
disciplines
# Out:
# array(['3x3 Basketball', 'Archery', 'Artistic Gymnastics',
#        'Artistic Swimming', 'Athletics', 'Baseball/Softball',
#        'Basketball', 'Beach Volleyball', 'Cycling Track', 'Fencing',
#        'Football', 'Handball', 'Hockey', 'Rhythmic Gymnastics',
#        'Rugby Sevens', 'Swimming', 'Table Tennis', 'Triathlon',
#        'Volleyball', 'Water Polo'], dtype=object)

# %%
a1 = all_athl.loc[all_athl["Discipline"]=="Table Tennis"]
a1
# Out:
#         Last_name First_name                       NOC    Discipline
# 20      Abdelaziz      Farah                     Egypt  Table Tennis
# 75        Achanta      Kamal                     India  Table Tennis
# 112      Afanador      Brian               Puerto Rico  Table Tennis
# 208       Alamian       Nima  Islamic Republic of Iran  Table Tennis
# 270    Alkhadrawi        Ali              Saudi Arabia  Table Tennis
# ...           ...        ...                       ...           ...
# 10900        Yuan        Jia                    France  Table Tennis
# 10959        Zaza       Hend      Syrian Arab Republic  Table Tennis
# 11004       Zhang       Lily  United States of America  Table Tennis
# 11010       Zhang         Mo                    Canada  Table Tennis
# 11040        Zhou        Xin  United States of America  Table Tennis
#
# [164 rows x 4 columns]

# %%
t1 = all_team.loc[all_team["Discipline"]=="Table Tennis"]
t1
# Out:
#                                    Name    Discipline  \
# 631                           Australia  Table Tennis
# 632          HU Heming / TAPPER Melissa  Table Tennis
# 633                           Australia  Table Tennis
# 634     FEGERL Stefan / POLCANOVA Sofia  Table Tennis
# 635                             Austria  Table Tennis
# 636                              Brazil  Table Tennis
# 637                              Brazil  Table Tennis
# 638                WANG Zhen / ZHANG Mo  Table Tennis
# 639                               China  Table Tennis
# 640                 XU Xin / LIU Shiwen  Table Tennis
# 641                               China  Table Tennis
# 642                      Chinese Taipei  Table Tennis
# 643          LIN Yun Ju / CHENG I Ching  Table Tennis
# 644                      Chinese Taipei  Table Tennis
# 645                             Croatia  Table Tennis
# 646      CAMPOS Jorge / FONSECA Daniela  Table Tennis
# ...

# %%
# Join athletes and teams to know which athletes teams
athl_team = pd.merge(a1, t1, on=["NOC","Discipline"])
athl_team
# Out:
#      Last_name First_name      NOC    Discipline                         Name  \
# 0    Abdelaziz      Farah    Egypt  Table Tennis                        Egypt
# 1    Abdelaziz      Farah    Egypt  Table Tennis    ASSAR Omar / MESHREF Dina
# 2    Abdelaziz      Farah    Egypt  Table Tennis                        Egypt
# 3        Assar       Omar    Egypt  Table Tennis                        Egypt
# 4        Assar       Omar    Egypt  Table Tennis    ASSAR Omar / MESHREF Dina
# ..         ...        ...      ...           ...                          ...
# 243     Pergel    Szandra  Hungary  Table Tennis                      Hungary
# 244       Pota   Georgina  Hungary  Table Tennis  SZUDI Adam / PERGEL Szandra
# 245       Pota   Georgina  Hungary  Table Tennis                      Hungary
# 246      Szudi       Adam  Hungary  Table Tennis  SZUDI Adam / PERGEL Szandra
# 247      Szudi       Adam  Hungary  Table Tennis                      Hungary
#
#              Event
# ...

# %%
# transform medals
# Apply BR: - extract only countries with gold medal >0 
# - extract only countries that have rank by total <=20
# 2. Medals/ranks type: 
# - Gold
# - Total
medals_path = "../Resources/Medals.csv"
all_med = pd.read_csv(medals_path)
all_med
# Out:
#     Rank                         NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# ..   ...                         ...   ...     ...     ...    ...
# 88    86                       Ghana     0       0       1      1
# 89    86                     Grenada     0       0       1      1
# 90    86                      Kuwait     0       0       1      1
# 91    86         Republic of Moldova     0       0       1      1
# 92    86        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               1
# 1               2
# 2               5
# 3               4
# 4               3
# ..            ...
# 88             77
# ...

# %%
# Remove silver, bronze
# all_med[["NOC", "Rank", "Rank by Total", "Gold", "Total", ]]
all_med = all_med.drop(["Silver", "Bronze"], axis=1)
all_med
# Out:
#     Rank                         NOC  Gold  Total  Rank by Total
# 0      1    United States of America    39    113              1
# 1      2  People's Republic of China    38     88              2
# 2      3                       Japan    27     58              5
# 3      4               Great Britain    22     65              4
# 4      5                         ROC    20     71              3
# ..   ...                         ...   ...    ...            ...
# 88    86                       Ghana     0      1             77
# 89    86                     Grenada     0      1             77
# 90    86                      Kuwait     0      1             77
# 91    86         Republic of Moldova     0      1             77
# 92    86        Syrian Arab Republic     0      1             77
#
# [93 rows x 5 columns]

# %%
# Apply BR: - extract only countries with gold medal >0 
# - extract only countries that have rank by total <=20
medals = all_med.loc[(all_med["Gold"]>0)&(all_med["Rank by Total"]<=20)]
medals
# Out:
#     Rank                         NOC  Gold  Total  Rank by Total
# 0      1    United States of America    39    113              1
# 1      2  People's Republic of China    38     88              2
# 2      3                       Japan    27     58              5
# 3      4               Great Britain    22     65              4
# 4      5                         ROC    20     71              3
# 5      6                   Australia    17     46              6
# 6      7                 Netherlands    10     36              9
# 7      8                      France    10     33             10
# 8      9                     Germany    10     37              8
# 9     10                       Italy    10     40              7
# 10    11                      Canada     7     24             11
# 11    12                      Brazil     7     21             12
# 12    13                 New Zealand     7     20             13
# ...

# %%
noc = medals["NOC"].values
noc
# Out:
# array(['United States of America', "People's Republic of China", 'Japan',
#        'Great Britain', 'ROC', 'Australia', 'Netherlands', 'France',
#        'Germany', 'Italy', 'Canada', 'Brazil', 'New Zealand', 'Cuba',
#        'Hungary', 'Republic of Korea', 'Poland', 'Spain', 'Switzerland',
#        'Turkey', 'Ukraine'], dtype=object)
